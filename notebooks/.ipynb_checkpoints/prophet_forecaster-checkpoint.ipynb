# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../scripts")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import utils

# %%
plt.rcParams["figure.figsize"] = (14,4)

# %%
data = pd.read_csv("../data/base_limpia.csv", parse_dates=["tiempo", "fecha pedido", "fecha liq"])

# %%
data.head()
# Out:
#       tiempo  nro factura    cliente categoria  tipo negocio localidad  \
# 0 2017-05-29     93315173  200008870        a5     mayorista  santa fe
# 1 2017-06-14     93368453  200008870        a5     mayorista  santa fe
# 2 2017-02-21     93074208  200008889        a3  supermercado  santa fe
# 3 2017-05-11     93270490  200008889        a3  supermercado  santa fe
# 4 2017-05-24     93309184  200008889        a3  supermercado  santa fe
#
#            direccion plaza/campaña  producto  nro pedido  ... u pedidas  \
# 0  av del valle 7199         plaza     90746     2736812  ...         1
# 1  av del valle 7199         plaza     90746     2765668  ...         1
# 2      gral.paz 5374         plaza     90740     2546672  ...         2
# 3      gral.paz 5374         plaza     90746     2702464  ...         1
# 4      gral.paz 5374         plaza     90746     2732609  ...         1
#
#    kg pedidos  fecha liq u entregadas  kg entregados  importe bruto  \
# 0       1.250 2017-05-29            1          1.250         231.70
# 1       1.250 2017-06-14            1          1.250         231.70
# 2       1.464 2017-02-21            2          1.464         324.96
# 3       1.250 2017-05-11            1          1.250         231.70
# 4       1.250 2017-05-24            1          1.250         231.70
#
#    importe factura  sucursal   longitud    latitud
# 0         12421.88  santa fe -60.691979 -31.602638
# 1         19944.84  santa fe -60.691979 -31.602638
# 2         24534.07  santa fe -60.686356 -31.620964
# 3         27204.63  santa fe -60.686356 -31.620964
# 4         16573.12  santa fe -60.686356 -31.620964
#
# [5 rows x 21 columns]

# %% [markdown]
# # Forecast por producto

# %% [markdown]
# Ahora armamos la tabla con los pedidos por día por producto.

# %%
u_producto = pd.pivot_table(
    data, 
    values="u pedidas", 
    index="tiempo", 
    columns="producto", 
    aggfunc="sum").asfreq("D")

# %%
u_producto.head()
# Out:
# producto    16034  16061  16062  16070  16071  16075  16076  16077  16080  \
# tiempo
# 2017-01-02    NaN    7.0    1.0   25.0   11.0    3.0    NaN    NaN    NaN
# 2017-01-03    NaN   21.0    NaN   27.0    2.0    NaN    NaN    NaN    NaN
# 2017-01-04    NaN    NaN    NaN    8.0    4.0    NaN    1.0    NaN    NaN
# 2017-01-05    NaN    3.0    NaN    6.0    3.0    NaN    NaN    NaN    NaN
# 2017-01-06    NaN    NaN    2.0   17.0    NaN    NaN    NaN    NaN    NaN
#
# producto    16081  ...  44151  44152  44154  44155  44157  44158  90739  \
# tiempo             ...
# 2017-01-02    1.0  ...    NaN    NaN    NaN    1.0    NaN    NaN    4.0
# 2017-01-03    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    3.0
# 2017-01-04    NaN  ...    NaN    NaN    NaN    1.0    NaN    1.0    NaN
# 2017-01-05    NaN  ...    NaN    NaN    NaN   10.0    NaN    1.0    NaN
# 2017-01-06    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# producto    90740  90745  90746
# tiempo
# 2017-01-02    1.0    NaN    NaN
# 2017-01-03    2.0    NaN    NaN
# 2017-01-04    NaN    NaN    NaN
# 2017-01-05    1.0    NaN    NaN
# 2017-01-06    NaN    NaN    NaN
#
# [5 rows x 64 columns]

# %%
u_producto = u_producto.reindex(index=pd.date_range(start="2017-01-01", end="2019-12-31", freq="D"))

# %%
utils.plot_grid(u_producto, n_cols=4, figsize=(16,32))

# %%
utils.get_amount_info(u_producto).plot(kind="bar")

# %%
u_producto_forecastable = utils.get_forecastables(u_producto, T=0.5, N=6)

# %%
utils.plot_grid(u_producto_forecastable, n_cols=3, figsize=(16, 8))

# %%
train_orig, test_orig = u_producto_forecastable[:"2018-12-31"].copy(), u_producto_forecastable["2019-01-01":].copy()

# %%
indicador_orig = pd.read_csv("../data/indicador_económico.csv", parse_dates=["fecha"]).set_index("fecha")

# %% [markdown]
# ### Prophet daily

# %%
from forecaster import ProphetForecaster

# %%
train = train_orig.copy()
test = test_orig.copy()

# %%
model = ProphetForecaster(yearly_seasonality=10)
model.fit(train)
fcst = model.predict(steps=365).asfreq("D")
# Out:
# Fitting...
# 6 of 6|###################################################################|100%
# Forecasting...
# 6 of 6|###################################################################|100%

# %%
fcst.head()
# Out:
#                16061                            16070                        \
#                 yhat yhat_lower yhat_upper       yhat yhat_lower yhat_upper
# ds
# 2017-01-02  7.607492   2.099727  21.172725  18.882908   4.999448  48.343864
# 2017-01-03  7.655358   2.088826  20.663738  18.468423   5.600623  44.784928
# 2017-01-04       NaN        NaN        NaN  18.132702   4.684775  47.976215
# 2017-01-05  7.752606   2.011842  21.105243  17.871038   4.918073  45.343919
# 2017-01-06       NaN        NaN        NaN  17.677949   4.901001  45.043563
#
#                16071                           44146                        \
#                 yhat yhat_lower yhat_upper      yhat yhat_lower yhat_upper
# ds
# 2017-01-02  7.443757   2.057600  23.972624  8.136911   2.492739  20.494908
# 2017-01-03  7.226782   2.094847  25.696021  7.933868   2.603948  21.947227
# 2017-01-04  7.029426   1.918778  22.171840  7.758169   2.217434  22.438873
# 2017-01-05  6.852098   1.858014  21.174302  7.610907   2.389933  20.241470
# 2017-01-06       NaN        NaN        NaN       NaN        NaN        NaN
#
#                44149                       44152
#                 yhat yhat_lower yhat_upper  yhat yhat_lower yhat_upper
# ds
# 2017-01-02  9.402126   2.507258  27.235218   NaN        NaN        NaN
# 2017-01-03  9.200642   2.644683  25.301892   NaN        NaN        NaN
# 2017-01-04  9.033849   2.569801  24.237590   NaN        NaN        NaN
# 2017-01-05  8.901382   2.818055  23.941016   NaN        NaN        NaN
# 2017-01-06  8.802618   2.612327  24.419957   NaN        NaN        NaN

# %%
f, axs = plt.subplots(3, 2, figsize=(16,16))
items = fcst.columns.get_level_values(0).drop_duplicates()
item_ax = zip(items, np.ravel(axs))
for item, ax in item_ax:
    utils.plot_fcst(fcst[item], train=train[item], test=test[item], ax=ax)

# %%
error = utils.calculate_error(fcst, test)

# %%
mae = error.abs().mean()
mae
# Out:
# 16061    26.650334
# 16070    34.349628
# 16071    23.811010
# 44146    15.362168
# 44149    19.649424
# 44152    11.610531
# dtype: float64

# %%
mape = mae / test.mean()
mape
# Out:
# 16061    0.550268
# 16070    0.464206
# 16071    0.598686
# 44146    0.515580
# 44149    0.527980
# 44152    0.559126
# dtype: float64

# %%
mae.mean()
# Out:
# 21.90551568820652

# %%
mape.mean()
# Out:
# 0.53597420282614

# %% [markdown]
# ##### With Regressors

# %%
indicador = indicador.copy()

# %%
model = ProphetForecaster(yearly_seasonality=10)
model.fit(train, indicador)
fcst = model.predict(steps=365, regressors=indicador).asfreq("D")
# Out:
# Fitting...
# 6 of 6|###################################################################|100%
# Forecasting...
# 6 of 6|###################################################################|100%

# %%
f, axs = plt.subplots(3, 2, figsize=(16,16))
items = fcst.columns.get_level_values(0).drop_duplicates()
item_ax = zip(items, np.ravel(axs))
for item, ax in item_ax:
    utils.plot_fcst(fcst[item], train=train[item], test=test[item], ax=ax)

# %%
error_reg = utils.calculate_error(fcst, test)

# %%
mae_reg = error_reg.abs().mean()
mae_reg
# Out:
# 16061    26.529938
# 16070    35.042257
# 16071    24.323758
# 44146    15.620693
# 44149    19.804124
# 44152    11.507714
# dtype: float64

# %%
mape_reg = mae_reg / test.mean()
mape_reg
# Out:
# 16061    0.547782
# 16070    0.473566
# 16071    0.611578
# 44146    0.524256
# 44149    0.532137
# 44152    0.554174
# dtype: float64

# %%
mae_reg.mean()
# Out:
# 22.13808067669728

# %%
mape_reg.mean()
# Out:
# 0.5405822974869393

# %% [markdown]
# ##### WIth holidays

# %%
model = ProphetForecaster(country_holidays="AR", yearly_seasonality=10)
model.fit(train)
fcst = model.predict(steps=365).asfreq("D")
# Out:
# Fitting...
# 6 of 6|###################################################################|100%
# Forecasting...
# 6 of 6|###################################################################|100%

# %%
f, axs = plt.subplots(3, 2, figsize=(16,16))
items = fcst.columns.get_level_values(0).drop_duplicates()
item_ax = zip(items, np.ravel(axs))
for item, ax in item_ax:
    utils.plot_fcst(fcst[item], train=train[item], test=test[item], ax=ax)

# %%
error_hol = utils.calculate_error(fcst, test)

# %%
mae_hol = error_hol.abs().mean()
mae_hol
# Out:
# 16061    26.535045
# 16070    34.453734
# 16071    23.818956
# 44146    15.251901
# 44149    19.415214
# 44152    11.507173
# dtype: float64

# %%
mape_hol = mae_hol / test.mean()
mape_hol
# Out:
# 16061    0.547887
# 16070    0.465613
# 16071    0.598886
# 44146    0.511879
# 44149    0.521687
# 44152    0.554148
# dtype: float64

# %%
mae_hol.mean()
# Out:
# 21.830336999080444

# %%
mape_hol.mean()
# Out:
# 0.5333500183512294

# %% [markdown]
# ## Prophet Weekly

# %%
train = train_orig.resample("W", closed="left").sum()
test = test_orig.resample("W", closed="left").sum()

# %%
train.head()
# Out:
# producto    44152  16061  16070  44146  16071  44149
# 2017-01-08    0.0   43.0   91.0   32.0   22.0   38.0
# 2017-01-15    7.0   27.0  100.0   34.0   45.0   46.0
# 2017-01-22   23.0   47.0   74.0   39.0   34.0   55.0
# 2017-01-29   19.0   15.0   57.0   28.0   23.0   31.0
# 2017-02-05   27.0   25.0   85.0   47.0   29.0   55.0

# %%
train.plot()

# %%
train[train == 0] = np.nan

# %%
model = ProphetForecaster(use_boxcox=True, yearly_seasonality=True)
model.fit(train)
fcst = model.predict(steps=52, freq="W").asfreq("W")
# Out:
# Fitting...
# 6 of 6|###################################################################|100%
# Forecasting...
# 6 of 6|###################################################################|100%

# %%
fcst.head()
# Out:
#                 16061                             16070             \
#                  yhat yhat_lower yhat_upper        yhat yhat_lower
# ds
# 2017-01-08  37.217074  21.668049  62.110083   99.057937  55.072404
# 2017-01-15  39.405668  23.008825  63.345972   88.611670  48.143896
# 2017-01-22  36.923241  20.891103  61.119397   93.967942  50.934704
# 2017-01-29  31.616602  17.916444  52.173617  100.742988  58.714388
# 2017-02-05  29.723825  16.602660  47.833280   99.013034  56.292272
#
#                             16071                            44146             \
#             yhat_upper       yhat yhat_lower yhat_upper       yhat yhat_lower
# ds
# 2017-01-08  153.582313  44.064672  23.496281  83.311528  40.780695  27.677153
# 2017-01-15  143.223895  41.842868  22.414402  75.908405  42.152920  29.866147
# 2017-01-22  148.297702  45.921813  25.064248  80.587761  48.850651  34.398503
# 2017-01-29  159.129160  49.776153  26.277079  88.863834  55.795280  39.750107
# 2017-02-05  147.796688  48.913947  26.906060  83.823298  57.312428  40.371429
#
#                            44149                             44152             \
#            yhat_upper       yhat yhat_lower  yhat_upper       yhat yhat_lower
# ds
# 2017-01-08  58.388955  56.271073  39.321211   79.833333        NaN        NaN
# 2017-01-15  61.083078  56.962274  40.317121   81.305968  19.491082  13.060817
# 2017-01-22  71.201476  63.329898  42.632247   89.599973  23.848156  15.906379
# 2017-01-29  80.222598  69.814315  46.909971   97.474811  31.258629  20.866363
# 2017-02-05  81.594630  72.790680  49.687632  101.124018  37.620622  24.799975
#
#
#            yhat_upper
# ds
# 2017-01-08        NaN
# 2017-01-15  29.695345
# 2017-01-22  35.765836
# 2017-01-29  46.183489
# 2017-02-05  53.975834

# %%
f, axs = plt.subplots(3, 2, figsize=(16,16))
items = fcst.columns.get_level_values(0).drop_duplicates()
item_ax = zip(items, np.ravel(axs))
for item, ax in item_ax:
    utils.plot_fcst(fcst[item], train=train[item], test=test[item], ax=ax)

# %%
error_w = utils.calculate_error(fcst, test)

# %%
mae_w = error_w.abs().mean()
mae_w
# Out:
# 16061    76.611663
# 16070    88.668436
# 16071    89.065099
# 44146    37.015524
# 44149    49.374722
# 44152    31.145868
# dtype: float64

# %%
mape_w = mae_w / test.mean()
mape_w
# Out:
# 16061    0.294169
# 16070    0.222059
# 16071    0.403699
# 44146    0.223952
# 44149    0.237551
# 44152    0.274117
# dtype: float64

# %%
mae_w.mean()
# Out:
# 61.98021855379114

# %%
mape_w.mean()
# Out:
# 0.27592444557453194

# %% [markdown]
# ##### With Regressors

# %%
indicador = indicador_orig.resample("W", closed="left").mean()

# %%
model = ProphetForecaster(yearly_seasonality=True)
model.fit(train, indicador)
fcst = model.predict(steps=52, freq="W", regressors=indicador).asfreq("W")
# Out:
# Fitting...
# 6 of 6|###################################################################|100%
# Forecasting...
# 6 of 6|###################################################################|100%

# %%
f, axs = plt.subplots(3, 2, figsize=(16,16))
items = fcst.columns.get_level_values(0).drop_duplicates()
item_ax = zip(items, np.ravel(axs))
for item, ax in item_ax:
    utils.plot_fcst(fcst[item], train=train[item], test=test[item], ax=ax)

# %%
error_w_reg = utils.calculate_error(fcst, test)

# %%
mae_w_reg = error_w_reg.abs().mean()
mae_w_reg
# Out:
# 16061    73.431749
# 16070    91.768705
# 16071    87.783777
# 44146    36.690911
# 44149    48.968597
# 44152    29.240496
# dtype: float64

# %%
mape_w_reg = mae_w_reg / test.mean()
mape_w_reg
# Out:
# 16061    0.281959
# 16070    0.229823
# 16071    0.397891
# 44146    0.221988
# 44149    0.235597
# 44152    0.257347
# dtype: float64

# %%
mae_w_reg.mean()
# Out:
# 61.31403917018756

# %%
mape_w_reg.mean()
# Out:
# 0.27076764388659486

# %% [markdown]
# ## Prophet 2-weekly

# %%
train = train_orig.resample("2W", closed="left").sum()
test = test_orig.resample("2W", closed="left").sum()

# %%
train.head()
# Out:
# producto    44152  16061  16070  44146  16071  44149
# 2017-01-15    7.0   70.0  191.0   66.0   67.0   84.0
# 2017-01-29   42.0   62.0  131.0   67.0   57.0   86.0
# 2017-02-12   60.0   82.0  196.0   84.0   83.0  132.0
# 2017-02-26  106.0  144.0  294.0  156.0  158.0  232.0
# 2017-03-12  138.0  176.0  322.0  246.0  164.0  417.0

# %%
train[train == 0] = np.nan

# %%
model = ProphetForecaster(use_boxcox=True, yearly_seasonality=True)
model.fit(train)
fcst = model.predict(steps=26, freq="2W").asfreq("2W")
# Out:
# Fitting...
# 6 of 6|###################################################################|100%
# Forecasting...
# 6 of 6|###################################################################|100%

# %%
fcst.head()
# Out:
#                  16061                               16070              \
#                   yhat  yhat_lower  yhat_upper        yhat  yhat_lower
# ds
# 2017-01-15   77.601077   59.933254   98.618608  188.934850  143.051078
# 2017-01-29   74.889317   58.150502   96.867141  193.190338  143.441584
# 2017-02-12   79.298256   62.145436  100.156531  223.258315  171.320214
# 2017-02-26  117.450705   93.323847  145.830566  271.352808  208.836815
# 2017-03-12  194.846241  161.302122  235.190912  450.993822  372.327820
#
#                              16071                               44146  \
#             yhat_upper        yhat  yhat_lower  yhat_upper        yhat
# ds
# 2017-01-15  242.589438   86.349225   55.785747  129.545518   85.739643
# 2017-01-29  246.353206   90.452060   57.754526  137.341228  104.455708
# 2017-02-12  286.577494  115.226599   76.381180  171.591488  113.276877
# 2017-02-26  344.879143  138.159289   91.100471  203.981008  144.347823
# 2017-03-12  547.928235  275.280514  191.090100  394.587622  274.417366
#
#                                          44149                          \
#             yhat_lower  yhat_upper        yhat  yhat_lower  yhat_upper
# ds
# 2017-01-15   65.591509  110.574556  111.781607   85.728042  140.218457
# 2017-01-29   80.218477  132.858516  137.049658  108.163952  175.122585
# 2017-02-12   88.515473  145.392910  153.540675  122.008314  192.949206
# 2017-02-26  112.308868  183.900388  211.929020  167.803800  261.111793
# 2017-03-12  218.757826  342.250340  394.447216  320.978539  490.840336
#
#                  44152
#                   yhat  yhat_lower  yhat_upper
# ds
# 2017-01-15   31.300245   18.310078   50.492565
# 2017-01-29   58.901338   37.174905   87.991330
# 2017-02-12   86.478974   57.852324  123.853087
# 2017-02-26   98.325752   66.611140  142.985216
# 2017-03-12  168.517780  120.782544  232.596804

# %%
f, axs = plt.subplots(3, 2, figsize=(16,16))
items = fcst.columns.get_level_values(0).drop_duplicates()
item_ax = zip(items, np.ravel(axs))
for item, ax in item_ax:
    utils.plot_fcst(fcst[item], train=train[item], test=test[item], ax=ax)

# %%
error_2w = utils.calculate_error(fcst, test)

# %%
mae_2w = error_2w.abs().mean()
mae_2w
# Out:
# 16061    143.219622
# 16070    129.017376
# 16071    145.383331
# 44146     59.827187
# 44149     78.051600
# 44152     61.969942
# dtype: float64

# %%
mape_2w = mae_2w / test.mean()
mape_2w
# Out:
# 16061    0.280151
# 16070    0.164602
# 16071    0.335701
# 44146    0.184399
# 44149    0.191303
# 44152    0.277846
# dtype: float64

# %%
mae_2w.mean()
# Out:
# 102.9115097034278

# %%
mape_2w.mean()
# Out:
# 0.23900031311307726

# %% [markdown]
# ### With regressors

# %%
indicador = indicador_orig.resample("2W", closed="left").mean()

# %%
model = ProphetForecaster(use_boxcox=True, yearly_seasonality=True)
model.fit(train)
fcst = model.predict(steps=26, freq="2W", regressors=indicador).asfreq("2W")
# Out:
# Fitting...
# 6 of 6|###################################################################|100%
# Forecasting...
# 6 of 6|###################################################################|100%

# %%
fcst.head()
# Out:
#                  16061                               16070              \
#                   yhat  yhat_lower  yhat_upper        yhat  yhat_lower
# ds
# 2017-01-15   77.601077   61.146841   99.369577  188.934850  140.515471
# 2017-01-29   74.889317   58.707163   94.415395  193.190338  143.423493
# 2017-02-12   79.298256   61.667481  101.357155  223.258315  167.016769
# 2017-02-26  117.450705   92.993668  145.292123  271.352808  211.241352
# 2017-03-12  194.846241  158.597396  233.692378  450.993822  367.943003
#
#                              16071                               44146  \
#             yhat_upper        yhat  yhat_lower  yhat_upper        yhat
# ds
# 2017-01-15  247.335389   86.349225   57.741139  132.614085   85.739643
# 2017-01-29  253.008054   90.452060   60.468852  140.206746  104.455708
# 2017-02-12  284.989192  115.226599   74.065469  165.851581  113.276877
# 2017-02-26  341.874340  138.159289   93.363849  204.578755  144.347823
# 2017-03-12  540.909885  275.280514  190.687835  392.012377  274.417366
#
#                                          44149                          \
#             yhat_lower  yhat_upper        yhat  yhat_lower  yhat_upper
# ds
# 2017-01-15   66.891825  110.294289  111.781607   87.710908  140.452678
# 2017-01-29   79.573197  132.797858  137.049658  107.319846  171.962297
# 2017-02-12   88.957303  145.570111  153.540675  124.035341  192.720093
# 2017-02-26  112.024453  182.337901  211.929020  172.295220  263.683327
# 2017-03-12  219.475368  346.172828  394.447216  321.841555  481.223484
#
#                  44152
#                   yhat  yhat_lower  yhat_upper
# ds
# 2017-01-15   31.300245   19.049772   50.053645
# 2017-01-29   58.901338   39.139003   86.329415
# 2017-02-12   86.478974   57.308853  123.640765
# 2017-02-26   98.325752   66.678211  139.646960
# 2017-03-12  168.517780  116.990040  228.470666

# %%
f, axs = plt.subplots(3, 2, figsize=(16,16))
items = fcst.columns.get_level_values(0).drop_duplicates()
item_ax = zip(items, np.ravel(axs))
for item, ax in item_ax:
    utils.plot_fcst(fcst[item], train=train[item], test=test[item], ax=ax)

# %%
error_2w_reg = utils.calculate_error(fcst, test)

# %%
mae_2w_reg = error_2w_reg.abs().mean()
mae_2w_reg
# Out:
# 16061    143.219622
# 16070    129.017376
# 16071    145.383331
# 44146     59.827187
# 44149     78.051600
# 44152     61.969942
# dtype: float64

# %%
mape_2w_reg = mae_2w_reg / test.mean()
mape_2w_reg
# Out:
# 16061    0.280151
# 16070    0.164602
# 16071    0.335701
# 44146    0.184399
# 44149    0.191303
# 44152    0.277846
# dtype: float64

# %%
mae_2w_reg.mean()
# Out:
# 102.9115097034278

# %%
mape_2w_reg.mean()
# Out:
# 0.23900031311307726

# %% [markdown]
# # Forecast por producto y región

# %%
u_producto_region = pd.pivot_table(
    data, 
    values="u pedidas", 
    index="tiempo", 
    columns=["producto", "sucursal"], 
    aggfunc="sum").asfreq("D")

# %%
u_producto_region = u_producto_region.reindex(index=pd.date_range(start="2017-01-01", end="2019-12-31", freq="D"))

# %%
u_producto_region.head()
# Out:
# producto      16034   16061            16062            16070           \
# sucursal   santa fe neuquen santa fe neuquen santa fe neuquen santa fe
# 2017-01-01      NaN     NaN      NaN     NaN      NaN     NaN      NaN
# 2017-01-02      NaN     NaN      7.0     NaN      1.0     NaN     25.0
# 2017-01-03      NaN     NaN     21.0     NaN      NaN     NaN     27.0
# 2017-01-04      NaN     NaN      NaN     NaN      NaN     NaN      8.0
# 2017-01-05      NaN     NaN      3.0     NaN      NaN     NaN      6.0
#
# producto     16071            16075  ...   44158            90739           \
# sucursal   neuquen santa fe neuquen  ... neuquen santa fe neuquen santa fe
# 2017-01-01     NaN      NaN     NaN  ...     NaN      NaN     NaN      NaN
# 2017-01-02     NaN     11.0     NaN  ...     NaN      NaN     NaN      4.0
# 2017-01-03     NaN      2.0     NaN  ...     NaN      NaN     NaN      3.0
# 2017-01-04     NaN      4.0     NaN  ...     NaN      1.0     NaN      NaN
# 2017-01-05     NaN      3.0     NaN  ...     NaN      1.0     NaN      NaN
#
# producto     90740            90745            90746
# sucursal   neuquen santa fe neuquen santa fe neuquen santa fe
# 2017-01-01     NaN      NaN     NaN      NaN     NaN      NaN
# 2017-01-02     NaN      1.0     NaN      NaN     NaN      NaN
# 2017-01-03     NaN      2.0     NaN      NaN     NaN      NaN
# 2017-01-04     NaN      NaN     NaN      NaN     NaN      NaN
# 2017-01-05     NaN      1.0     NaN      NaN     NaN      NaN
#
# [5 rows x 120 columns]

# %%
utils.get_amount_info(u_producto_region).plot(kind="bar", figsize=(16,4))
plt.xticks(ticks=[]);

# %%
u_producto_region_forecastable = utils.get_forecastables(u_producto_region, T=0.5, N=12).sort_index(axis=1)

# %%
utils.plot_grid(u_producto_region_forecastable, n_cols=3, figsize=(16, 20))

# %%
train, test = u_producto_region_forecastable[:"2018-12-31"], u_producto_region_forecastable["2019-01-01":]

# %% [markdown]
# ### Prophet

# %%
model = ProphetForecaster(yearly_seasonality=True)
model.fit(train)
fcst = model.predict(steps=365).asfreq("D")
# Out:
# Fitting...
# 12 of 12|#################################################################|100%
# Forecasting...
# 12 of 12|#################################################################|100%

# %%
fcst.head(10)
# Out:
#                16061                           16062                        \
#             santa fe                        santa fe
#                 yhat yhat_lower yhat_upper      yhat yhat_lower yhat_upper
# ds
# 2017-01-02  5.386853   1.519911  16.718836  2.229475   0.714846   7.416428
# 2017-01-03  5.406998   1.486957  15.177959       NaN        NaN        NaN
# 2017-01-04       NaN        NaN        NaN       NaN        NaN        NaN
# 2017-01-05  5.441283   1.523990  15.567870       NaN        NaN        NaN
# 2017-01-06       NaN        NaN        NaN  2.306941   0.716911   7.172256
# 2017-01-07  5.456751   1.632894  16.616715       NaN        NaN        NaN
# 2017-01-08       NaN        NaN        NaN       NaN        NaN        NaN
# 2017-01-09       NaN        NaN        NaN  2.358351   0.724658   7.280400
# 2017-01-10       NaN        NaN        NaN  2.370805   0.768433   7.300094
# 2017-01-11  5.395641   1.472951  16.582660  2.379988   0.726485   7.910195
#
#                 16070                           16071  ...      44149  \
#              santa fe                        santa fe  ...    neuquen
#                  yhat yhat_lower yhat_upper      yhat  ... yhat_upper
# ds                                                     ...
# 2017-01-02  14.953977   4.400177  40.947193  5.567765  ...        NaN
# 2017-01-03  14.656313   4.272611  39.497418  5.496262  ...        NaN
# 2017-01-04  14.414836   4.302857  39.777223  5.432328  ...        NaN
# 2017-01-05  14.227067   4.500825  38.440916  5.375307  ...        NaN
# 2017-01-06  14.089813   4.244959  38.064549       NaN  ...        NaN
# 2017-01-07  13.999225   4.194383  39.417114  5.279075  ...        NaN
# 2017-01-08        NaN        NaN        NaN       NaN  ...        NaN
# 2017-01-09        NaN        NaN        NaN  5.201425  ...        NaN
# 2017-01-10  13.960102   4.228598  37.931643  5.167639  ...        NaN
# 2017-01-11  14.006174   3.724037  37.547420  5.136246  ...        NaN
#
#                                                44152                        \
#             santa fe                        santa fe
#                 yhat yhat_lower yhat_upper      yhat yhat_lower yhat_upper
# ds
# 2017-01-02  7.859500   2.006633  28.175332       NaN        NaN        NaN
# 2017-01-03  7.707466   1.988707  25.298933       NaN        NaN        NaN
# 2017-01-04  7.570713   1.884751  24.728677       NaN        NaN        NaN
# 2017-01-05  7.449867   1.964917  23.741569       NaN        NaN        NaN
# 2017-01-06  7.345328   1.880127  22.935387       NaN        NaN        NaN
# 2017-01-07  7.257265   1.856766  23.218453       NaN        NaN        NaN
# 2017-01-08       NaN        NaN        NaN       NaN        NaN        NaN
# 2017-01-09       NaN        NaN        NaN       NaN        NaN        NaN
# 2017-01-10  7.090192   1.656853  22.984187       NaN        NaN        NaN
# 2017-01-11  7.065153   1.923090  23.253937  3.503355   1.065344  10.967287
#
#                44155
#             santa fe
#                 yhat yhat_lower yhat_upper
# ds
# 2017-01-02  3.829905   1.292983  11.890580
# 2017-01-03       NaN        NaN        NaN
# 2017-01-04  3.911377   1.265298  12.543543
# 2017-01-05  3.942978   1.279841  13.097970
# 2017-01-06       NaN        NaN        NaN
# 2017-01-07  3.979607   1.323666  12.736307
# 2017-01-08       NaN        NaN        NaN
# 2017-01-09       NaN        NaN        NaN
# 2017-01-10  3.954297   1.385121  13.079898
# 2017-01-11  3.923883   1.275527  11.955542
#
# [10 rows x 36 columns]

# %%
f, axs = plt.subplots(6, 2, figsize=(16,24))
items = fcst.columns.droplevel(2).drop_duplicates()
item_ax = zip(items, np.ravel(axs))
for item, ax in item_ax:
    utils.plot_fcst(fcst[item], train=train[item], test=test[item], ax=ax)

# %%
item = (44149, "santa fe")
utils.plot_fcst(fcst[item], train[item], test[item])

# %%
error_prophet = fcst.loc["2019-01-01":"2019-12-31", pd.IndexSlice[:, :,"yhat"]].droplevel(2, axis=1) - test
mae_prophet = error_prophet.abs().mean().mean()
mae_prophet
# Out:
# 14.927661483012391
